# %%
import os
from dataset_processing import remove_quotes_from_file, filter_by_max_words, clean_text, write_training_file, convert_stopwords_to_lower_case
import pandas as pd
import platform
import json

# %%
# set the filepaths for the data
operating_system = platform.system()
if operating_system == 'Windows':
    raise Exception("not used on Windows yet")
elif operating_system == 'Linux':
    train_dir = "/run/user/1000/gvfs/google-drive:host=gmail.com,user=cjameswalmsley/0AG4X1_cOZQRnUk9PVA/0B24X1_cOZQRnVjZEemxXd3BNSTQ/1SSfZglixkSB5aj0qMv2BsDojVhxNOv0o/11BZhonitY-Jfw5xqM1xAl5TjJPRDRKHr/1OyCmWPf_7PH1bCc-5GLvBdo-gvEvJsiP/1dgL8C9ydesEz3jM28e55yGR9PECRtjaA/1_z0x1Ym8ceREizMlb1mk29msDhvfy2xg/1951JmEhJWAQjilgGc7T00-z9bbiJwNM3"
elif operating_system == 'Darwin': #macOS
    train_dir = "/Users/chris/Library/CloudStorage/GoogleDrive-cjameswalmsley@gmail.com/My Drive/Shared with Julia/Education/Kent University/PhD/work/annabell/training"
else:
    raise Exception("unsupported OS")

pre_training_dir = "pre_training"
statements_filepath = os.path.join(pre_training_dir, "nyc_statements.txt")
train_filename = "declarative_sentences_train_gemma3:1b_20250707_174634.tsv"
train_filepath = os.path.join(train_dir, train_filename)
statements_json_filepath = os.path.join(pre_training_dir, "nyc_statements_response.json")
questions_json_filepath = os.path.join(pre_training_dir, "nyc_questions_response.json")
statements_filepath = os.path.join(pre_training_dir, "nyc_statements.txt")
questions_filepath = os.path.join(pre_training_dir, "nyc_questions.txt")

# %%
#load and clean the nyc training data
train_filepath = remove_quotes_from_file(train_filepath)
train_df = pd.read_csv(train_filepath, sep="\t")
train_df = train_df.dropna()
filtered_train_df = filter_by_max_words(train_df, max_words=20)
filtered_train_df["response_question"] = clean_text(filtered_train_df["response_question"], True)
filtered_train_df["response_answer"] = clean_text(filtered_train_df["response_answer"], False)
filtered_train_df["statement"] = clean_text(filtered_train_df["statement"], False)
filtered_train_df.reset_index(drop=True, inplace=True)
filtered_train_df.info()
# Out:
# Cleaned data saved to /Users/chris/Library/CloudStorage/GoogleDrive-cjameswalmsley@gmail.com/My Drive/Shared with Julia/Education/Kent University/PhD/work/annabell/training/declarative_sentences_train_gemma3:1b_20250707_174634_cleaned.tsv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 798 non-null    object
#  1   title              798 non-null    object
#  2   question           798 non-null    object
#  3   answer             798 non-null    object
#  4   response_question  798 non-null    object
#  5   response_answer    798 non-null    object
#  6   statement          798 non-null    object
# dtypes: object(7)
# memory usage: 43.8+ KB
# /var/folders/cv/z7xz0c3n3nd4c26hj7g01n7w0000gn/T/ipykernel_24017/1635968978.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_train_df["response_question"] = clean_text(filtered_train_df["response_question"], True)
# /var/folders/cv/z7xz0c3n3nd4c26hj7g01n7w0000gn/T/ipykernel_24017/1635968978.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_train_df["response_answer"] = clean_text(filtered_train_df["response_answer"], False)
# /var/folders/cv/z7xz0c3n3nd4c26hj7g01n7w0000gn/T/ipykernel_24017/1635968978.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_train_df["statement"] = clean_text(filtered_train_df["statement"], False)

# %%
write_training_file(filtered_train_df, statements_filepath)
with open(statements_filepath, "r") as training_file:
    training_lines = training_file.readlines()
# Out:
# file created: pre_training/nyc_statements.txt

# %%
questions = filtered_train_df["question"]
with open(questions_filepath, "w") as questions_file:
    for question in questions:
        questions_file.write(f"{question}\n")
with open(questions_filepath, "r") as questions_file:
    questions_lines = questions_file.readlines()
for line in questions_lines[:5]:
    print(line)
# Out:
# What city in the United States has the highest population?
#
# In what city is the United Nations based?
#
# What city has been called the cultural capital of the world?
#
# What American city welcomes the largest number of legal immigrants?
#
# The major gateway for immigration has been which US city?

# %% [markdown]
# ##Find a selection of training samples from the statements and questions
# * Take the contents of the 2 files and ask an LLM to categorise the questions and statements
# * The following prompt can be used to categorise:
# > TASK: categorise the provided list of sentences by grammatical structure
# RESPONSE FORMAT: provide the response in JSON format with each row formatted as {"category":"<INSERT CATEGORY>", "sentence":"<INSERT SENTENCE>"}
# >

# %%
with open(statements_json_filepath, 'r') as statements_json_file:
    statements_json_lines = statements_json_file.readlines()
statements = [json.loads(line) for line in statements_json_lines if line.strip()]
print(statements[:5])
statements_df = pd.DataFrame(statements)
statements_df = statements_df[statements_df["category"] != "INTERROGATIVE"]
statements_df.groupby('category').count()
# Out:
# [{'category': 'SUBJECT_LINKING_VERB_COMPLEMENT', 'sentence': 'York is a city in the United States with the highest population'}, {'category': 'PASSIVE_CONSTRUCTION', 'sentence': 'The United Nations is headquartered in New York'}, {'category': 'PASSIVE_CONSTRUCTION', 'sentence': 'New York has been called the cultural capital of the world'}, {'category': 'SUBJECT_VERB_OBJECT', 'sentence': 'New York welcomes the largest number of legal immigrants'}, {'category': 'SUBJECT_LINKING_VERB_COMPLEMENT', 'sentence': 'The major gateway for immigration has been New York City'}]
#                                  sentence
# category
# ATTRIBUTE_IS_VALUE                    117
# EXISTENTIAL_SENTENCE                   26
# PASSIVE_CONSTRUCTION                  185
# PREPOSITIONAL_PHRASE_FRONTING          33
# SUBJECT_LINKING_VERB_COMPLEMENT       148
# SUBJECT_VERB_OBJECT                   270

# %%
with open(questions_json_filepath, 'r') as questions_json_file:
    questions_json_lines = questions_json_file.readlines()
questions = [json.loads(line) for line in questions_json_lines if line.strip()]
print(questions[:5])
questions_df = pd.DataFrame(questions)
questions_df.groupby('category').count()
# Out:
# [{'category': 'WHAT_QUESTION', 'sentence': 'What city in the United States has the highest population?'}, {'category': 'WHERE_IN_ON_AT_QUESTION', 'sentence': 'In what city is the United Nations based?'}, {'category': 'WHAT_QUESTION', 'sentence': 'What city has been called the cultural capital of the world?'}, {'category': 'WHAT_QUESTION', 'sentence': 'What American city welcomes the largest number of legal immigrants?'}, {'category': 'WHICH_QUESTION', 'sentence': 'The major gateway for immigration has been which US city?'}]
#                          sentence
# category
# HOW_QUESTION                  179
# WHAT_QUESTION                 400
# WHEN_QUESTION                  18
# WHERE_IN_ON_AT_QUESTION       126
# WHICH_QUESTION                 69
# WHO_QUESTION                   25

# %%
#add the categories to the filtered_train_df
def add_categories_to_df(df, category_column, sentences):
    categories = []
    new_column_name = category_column + "_category"
    for sentence in df[category_column]:
        matching_row = sentences[sentences["sentence"] == sentence]
        if not matching_row.empty:
            categories.append(matching_row["category"].values[0])
        else:
            categories.append(None)
    df[new_column_name] = categories
    return df

# %%
filtered_train_df_with_categories = add_categories_to_df(filtered_train_df, "statement", statements_df)
filtered_train_df_with_categories = add_categories_to_df(filtered_train_df_with_categories, "question", questions_df)
filtered_train_df_with_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  798 non-null    object
#  1   title               798 non-null    object
#  2   question            798 non-null    object
#  3   answer              798 non-null    object
#  4   response_question   798 non-null    object
#  5   response_answer     798 non-null    object
#  6   statement           798 non-null    object
#  7   statement_category  608 non-null    object
#  8   question_category   793 non-null    object
# dtypes: object(9)
# memory usage: 56.2+ KB
# /var/folders/cv/z7xz0c3n3nd4c26hj7g01n7w0000gn/T/ipykernel_24017/530804637.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_name] = categories
# /var/folders/cv/z7xz0c3n3nd4c26hj7g01n7w0000gn/T/ipykernel_24017/530804637.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_name] = categories

# %%
filtered_train_df_with_categories.dropna(inplace=True)
filtered_train_df_with_categories.reset_index(drop=True, inplace=True)
filtered_train_df_with_categories
# Out:
# /var/folders/cv/z7xz0c3n3nd4c26hj7g01n7w0000gn/T/ipykernel_24017/2512786238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_train_df_with_categories.dropna(inplace=True)
#                            id          title  \
# 0    56ce304daab44d1400b8850f  New_York_City
# 1    56ce304daab44d1400b88510  New_York_City
# 2    56ce304daab44d1400b88511  New_York_City
# 3    56cf5d41aab44d1400b89130  New_York_City
# 4    56cf5d41aab44d1400b89131  New_York_City
# ..                        ...            ...
# 599  56d1204617492d1400aab9fd  New_York_City
# 600  56d1218c17492d1400aaba1e  New_York_City
# 601  56d1218c17492d1400aaba1f  New_York_City
# 602  56d1218c17492d1400aaba20  New_York_City
# 603  56d1218c17492d1400aaba21  New_York_City
#
#                                               question         answer  \
# 0            In what city is the United Nations based?       New York
# 1    What city has been called the cultural capital...       New York
# 2    What American city welcomes the largest number...       New York
# 3    The major gateway for immigration has been whi...  New York City
# 4    The most populated city in the United States i...  New York City
# ..                                                 ...            ...
# 599   In what borough is the New York City Hall found?      Manhattan
# 600  What ZIP code was responsible for the greatest...          10021
# 601  How much money in cents does New York City rec...             83
# 602  How much more money does the city give to the ...    $11 billion
# 603  Each year, how much more money does New York C...  $11.4 billion
#
#                                      response_question      response_answer  \
# 0           ? In what city is the United Nations based             New York
# 1    ? What city has been called the cultural capit...             New York
# 2    ? What American city welcomes the largest numb...             New York
# 3    ? The major gateway for immigration has been w...        New York City
# 4    ? The most populated city in the United States...        New York City
# ..                                                 ...                  ...
# 599  ? In what borough is the New York City Hall found            Manhattan
# 600  ? What ZIP code was responsible for the greate...                10021
# 601  ? How much money in cents does New York City r...                   83
# 602  ? How much more money does the city give to th...           11 billion
# 603  ? Each year how much more money does New York ...   11 point 4 billion
#
#                                              statement  \
# 0      The United Nations is headquartered in New York
# 1    New York has been called the cultural capital ...
# 2    New York welcomes the largest number of legal ...
# 3    The major gateway for immigration has been New...
# 4    The most populated city in the United States i...
# ..                                                 ...
# 599     The New York City Hall is located in Manhattan
# 600  The ZIP code 10021 was responsible for the gre...
# 601  New York City receives 83 cents for every doll...
# 602  The city gives 11 billion more to the state of...
# 603  Each year New York City gives 11 point 4 billi...
#
#                   statement_category        question_category
# 0               PASSIVE_CONSTRUCTION  WHERE_IN_ON_AT_QUESTION
# 1               PASSIVE_CONSTRUCTION            WHAT_QUESTION
# 2                SUBJECT_VERB_OBJECT            WHAT_QUESTION
# 3    SUBJECT_LINKING_VERB_COMPLEMENT           WHICH_QUESTION
# 4    SUBJECT_LINKING_VERB_COMPLEMENT           WHICH_QUESTION
# ..                               ...                      ...
# 599             PASSIVE_CONSTRUCTION  WHERE_IN_ON_AT_QUESTION
# 600  SUBJECT_LINKING_VERB_COMPLEMENT            WHAT_QUESTION
# 601              SUBJECT_VERB_OBJECT             HOW_QUESTION
# 602              SUBJECT_VERB_OBJECT             HOW_QUESTION
# 603              SUBJECT_VERB_OBJECT             HOW_QUESTION
#
# [604 rows x 9 columns]

# %%
print(filtered_train_df_with_categories.groupby(["question_category"]).count())
print(filtered_train_df_with_categories.groupby(["statement_category"]).count())
# Out:
#                           id  title  question  answer  response_question  \
# question_category
# HOW_QUESTION             133    133       133     133                133
# WHAT_QUESTION            329    329       329     329                329
# WHEN_QUESTION              1      1         1       1                  1
# WHERE_IN_ON_AT_QUESTION   69     69        69      69                 69
# WHICH_QUESTION            52     52        52      52                 52
# WHO_QUESTION              20     20        20      20                 20
#
#                          response_answer  statement  statement_category
# question_category
# HOW_QUESTION                         133        133                 133
# WHAT_QUESTION                        329        329                 329
# WHEN_QUESTION                          1          1                   1
# WHERE_IN_ON_AT_QUESTION               69         69                  69
# WHICH_QUESTION                        52         52                  52
# WHO_QUESTION                          20         20                  20
#                                   id  title  question  answer  \
# statement_category
# ATTRIBUTE_IS_VALUE                75     75        75      75
# EXISTENTIAL_SENTENCE              25     25        25      25
# PASSIVE_CONSTRUCTION             139    139       139     139
# PREPOSITIONAL_PHRASE_FRONTING     27     27        27      27
# SUBJECT_LINKING_VERB_COMPLEMENT  136    136       136     136
# SUBJECT_VERB_OBJECT              202    202       202     202
#
#                                  response_question  response_answer  \
# statement_category
# ATTRIBUTE_IS_VALUE                              75               75
# EXISTENTIAL_SENTENCE                            25               25
# PASSIVE_CONSTRUCTION                           139              139
# PREPOSITIONAL_PHRASE_FRONTING                   27               27
# SUBJECT_LINKING_VERB_COMPLEMENT                136              136
# SUBJECT_VERB_OBJECT                            202              202
#
#                                  statement  question_category
# statement_category
# ATTRIBUTE_IS_VALUE                      75                 75
# EXISTENTIAL_SENTENCE                    25                 25
# PASSIVE_CONSTRUCTION                   139                139
# PREPOSITIONAL_PHRASE_FRONTING           27                 27
# SUBJECT_LINKING_VERB_COMPLEMENT        136                136
# SUBJECT_VERB_OBJECT                    202                202

# %%
# Function to randomly select a sample of statements and questions from each category
def select_random_samples(df, category_column, sample_size=3):
    samples = []
    for category in df[category_column].unique():
        category_samples = df[df[category_column] == category].sample(n=min(sample_size, len(df[df[category_column] == category])), random_state=42)
        samples.append(category_samples)
    return pd.concat(samples).reset_index(drop=True)

sample_statements_df = select_random_samples(filtered_train_df_with_categories, "statement_category")
sample_questions_df = select_random_samples(filtered_train_df_with_categories, "question_category")

# %%
print(sample_questions_df.groupby("question_category").count())
print(sample_statements_df.groupby("statement_category").count())
# Out:
#                          id  title  question  answer  response_question  \
# question_category
# HOW_QUESTION              3      3         3       3                  3
# WHAT_QUESTION             3      3         3       3                  3
# WHEN_QUESTION             1      1         1       1                  1
# WHERE_IN_ON_AT_QUESTION   3      3         3       3                  3
# WHICH_QUESTION            3      3         3       3                  3
# WHO_QUESTION              3      3         3       3                  3
#
#                          response_answer  statement  statement_category
# question_category
# HOW_QUESTION                           3          3                   3
# WHAT_QUESTION                          3          3                   3
# WHEN_QUESTION                          1          1                   1
# WHERE_IN_ON_AT_QUESTION                3          3                   3
# WHICH_QUESTION                         3          3                   3
# WHO_QUESTION                           3          3                   3
#                                  id  title  question  answer  \
# statement_category
# ATTRIBUTE_IS_VALUE                3      3         3       3
# EXISTENTIAL_SENTENCE              3      3         3       3
# PASSIVE_CONSTRUCTION              3      3         3       3
# PREPOSITIONAL_PHRASE_FRONTING     3      3         3       3
# SUBJECT_LINKING_VERB_COMPLEMENT   3      3         3       3
# SUBJECT_VERB_OBJECT               3      3         3       3
#
#                                  response_question  response_answer  \
# statement_category
# ATTRIBUTE_IS_VALUE                               3                3
# EXISTENTIAL_SENTENCE                             3                3
# PASSIVE_CONSTRUCTION                             3                3
# PREPOSITIONAL_PHRASE_FRONTING                    3                3
# SUBJECT_LINKING_VERB_COMPLEMENT                  3                3
# SUBJECT_VERB_OBJECT                              3                3
#
#                                  statement  question_category
# statement_category
# ATTRIBUTE_IS_VALUE                       3                  3
# EXISTENTIAL_SENTENCE                     3                  3
# PASSIVE_CONSTRUCTION                     3                  3
# PREPOSITIONAL_PHRASE_FRONTING            3                  3
# SUBJECT_LINKING_VERB_COMPLEMENT          3                  3
# SUBJECT_VERB_OBJECT                      3                  3

# %%
statements_mask = filtered_train_df_with_categories["statement"].isin(sample_statements_df["statement"])
statements_mask.value_counts()
# Out:
# statement
# False    586
# True      18
# Name: count, dtype: int64

# %%
questions_mask = filtered_train_df_with_categories["question"].isin(sample_questions_df["question"])
questions_mask.value_counts()
# Out:
# question
# False    588
# True      16
# Name: count, dtype: int64

# %%
filtered_samples_df = filtered_train_df_with_categories[statements_mask | questions_mask].copy()
filtered_samples_df.reset_index(drop=True, inplace=True)
filtered_samples_df["statement"] = filtered_samples_df["statement"].apply(lambda x: convert_stopwords_to_lower_case(x))
filtered_samples_df
# Out:
#                           id          title  \
# 0   56ce304daab44d1400b8850f  New_York_City
# 1   56cf9f16234ae51400d9be30  New_York_City
# 2   56ce33aaaab44d1400b8856a  New_York_City
# 3   56ce34c7aab44d1400b88595  New_York_City
# 4   56cfb206234ae51400d9be91  New_York_City
# 5   56cfb5cb234ae51400d9beb7  New_York_City
# 6   56cee30faab44d1400b88bf3  New_York_City
# 7   56cee638aab44d1400b88c34  New_York_City
# 8   56cee7edaab44d1400b88c67  New_York_City
# 9   56cfdde6234ae51400d9bfa8  New_York_City
# 10  56cef595aab44d1400b88d21  New_York_City
# 11  56cfdef3234ae51400d9bfc1  New_York_City
# 12  56cfe133234ae51400d9bfe1  New_York_City
# 13  56cf1aa6aab44d1400b88d87  New_York_City
# 14  56cf1d3baab44d1400b88da9  New_York_City
# 15  56cfe53a234ae51400d9c025  New_York_City
# 16  56cfe77b234ae51400d9c055  New_York_City
# 17  56cf3629aab44d1400b88e64  New_York_City
# 18  56cf36e5aab44d1400b88e72  New_York_City
# 19  56cf37b9aab44d1400b88e85  New_York_City
# 20  56cff1bb234ae51400d9c138  New_York_City
# 21  56cf5478aab44d1400b89000  New_York_City
# 22  56cf55aeaab44d1400b89030  New_York_City
# 23  56cfac79234ae51400d9be51  New_York_City
# 24  56cffb63234ae51400d9c1e5  New_York_City
# 25  56cfafaf234ae51400d9be68  New_York_City
# 26  56d1099d17492d1400aab7c6  New_York_City
# 27  56d10c8c17492d1400aab811  New_York_City
# 28  56d005d9234ae51400d9c284  New_York_City
# 29  56d1100317492d1400aab884  New_York_City
# 30  56d114ae17492d1400aab8bd  New_York_City
# 31  56d00b23234ae51400d9c2c3  New_York_City
# 32  56d00bc5234ae51400d9c2ce  New_York_City
# 33  56d11faa17492d1400aab9eb  New_York_City
#
#                                              question  \
# 0           In what city is the United Nations based?
# 1        How many school and universities are in NYC?
# 2           What was the name of the Lenape homeland?
# 3               Who commanded the Spanish expedition?
# 4   What was the myth that Manhattan was bought fo...
# 5   When was as African burial ground discovered a...
# 6   What notable catastrophe took place under the ...
# 7   About how many people died during the Draft Ri...
# 8   In the early 1920s, what was the second most h...
# 9   How many leader terrorists of Al Quada were in...
# 10  In what geographical region of the United Stat...
# 11  The Hudson River separates NYC from which US s...
# 12             How many square miles are land in NYC?
# 13  What floor of the Chrysler Building has sculpt...
# 14        What month in New York City is the coldest?
# 15  The mean snowfall between 1981 and 2010 in NYC...
# 16         What is the largest park in New York City?
# 17  What New York borough contains the highest pop...
# 18  What borough has the largest population of eth...
# 19  How many Hispanic people live in the New York ...
# 20  The Two highest advertising agencies in the wo...
# 21  Who was the previous overseer of the London in...
# 22          In what borough is Silicon Alley located?
# 23  How much money does the New York film and tele...
# 24  How many newspaper offices are located in New ...
# 25  What is the name of the city's public televisi...
# 26  Who ranked New York as the fashion capital of ...
# 27          How many restaurants is New York home to?
# 28  Which town do the New Jersey Devils hockey tea...
# 29  At what venue does the Amateur Boxing Golden G...
# 30  What percentage of New York households don't o...
# 31   Which bridge in NYC is the busiest in the world?
# 32  Who was the first person to drive through The ...
# 33  What numbered department of the Supreme Court ...
#
#                                  answer  \
# 0                              New York
# 1                                   120
# 2                          Lenapehoking
# 3                         Estêvão Gomes
# 4                           glass beads
# 5                                 1990s
# 6                Great Fire of New York
# 7                                   120
# 8                                London
# 9                                    10
# 10                         Northeastern
# 11                           New Jersey
# 12                                304.8
# 13                                 61st
# 14                              January
# 15                                 25.8
# 16                      Pelham Bay Park
# 17                               Queens
# 18                            the Bronx
# 19                          4.8 million
# 20  Omnicom Group and Interpublic Group
# 21          British Bankers Association
# 22                            Manhattan
# 23                         $7.1 billion
# 24                        More than 200
# 25                                NYCTV
# 26          the Global Language Monitor
# 27                               24,000
# 28                               Newark
# 29                Madison Square Garden
# 30                                  52%
# 31         The George Washington Bridge
# 32      President Franklin D. Roosevelt
# 33                               Second
#
#                                     response_question  \
# 0          ? In what city is the United Nations based
# 1       ? How many school and universities are in NYC
# 2          ? What was the name of the Lenape homeland
# 3              ? Who commanded the Spanish expedition
# 4   ? What was the myth that Manhattan was bought ...
# 5   ? When was as African burial ground discovered...
# 6   ? What notable catastrophe took place under th...
# 7   ? About how many people died during the Draft ...
# 8   ? In the early 1920s what was the second most ...
# 9   ? How many leader terrorists of Al Quada were ...
# 10  ? In what geographical region of the United St...
# 11  ? The Hudson River separates NYC from which US...
# 12            ? How many square miles are land in NYC
# 13  ? What floor of the Chrysler Building has scul...
# 14       ? What month in New York City is the coldest
# 15  ? The mean snowfall between 1981 and 2010 in N...
# 16        ? What is the largest park in New York City
# 17  ? What New York borough contains the highest p...
# 18  ? What borough has the largest population of e...
# 19  ? How many Hispanic people live in the New Yor...
# 20  ? The Two highest advertising agencies in the ...
# 21  ? Who was the previous overseer of the London ...
# 22         ? In what borough is Silicon Alley located
# 23  ? How much money does the New York film and te...
# 24  ? How many newspaper offices are located in Ne...
# 25  ? What is the name of the citys public televis...
# 26  ? Who ranked New York as the fashion capital o...
# 27         ? How many restaurants is New York home to
# 28  ? Which town do the New Jersey Devils hockey t...
# 29  ? At what venue does the Amateur Boxing Golden...
# 30  ? What percentage of New York households dont ...
# 31  ? Which bridge in NYC is the busiest in the world
# 32  ? Who was the first person to drive through Th...
# 33  ? What numbered department of the Supreme Cour...
#
#                         response_answer  \
# 0                              New York
# 1                                   120
# 2                          Lenapehoking
# 3                         Estevao Gomes
# 4                           glass beads
# 5                                 1990s
# 6                Great Fire of New York
# 7                                   120
# 8                                London
# 9                                    10
# 10                         Northeastern
# 11                           New Jersey
# 12                          304 point 8
# 13                                 61st
# 14                              January
# 15                           25 point 8
# 16                      Pelham Bay Park
# 17                               Queens
# 18                            the Bronx
# 19                    4 point 8 million
# 20  Omnicom Group and Interpublic Group
# 21          British Bankers Association
# 22                            Manhattan
# 23                    7 point 1 billion
# 24                        More than 200
# 25                                NYCTV
# 26          the Global Language Monitor
# 27                                24000
# 28                               Newark
# 29                Madison Square Garden
# 30                                   52
# 31         The George Washington Bridge
# 32       President Franklin D Roosevelt
# 33                               Second
#
#                                             statement  \
# 0     the United Nations is headquartered in New York
# 1        there are 120 school and universities in NYC
# 2            the Lenapehoking was the Lenape homeland
# 3      Estevao Gomes commanded the Spanish expedition
# 4   General Peter Minuit acquired Manhattan Island...
# 5   after the building of new courthouse African b...
# 6   Great Fire of New York took place under the Br...
# 7   during the Draft Riots of 1863 approximately 1...
# 8   in the early 1920s London was the second most ...
# 9   the number of leader terrorists of Al Quada di...
# 10  New York City is located in the Northeastern r...
# 11  the Hudson River separates New Jersey from the...
# 12  the area of land in New York City is 304 point...
# 13  the sculptures of eagles are located on the 61...
# 14  in January New York City experiences the colde...
# 15  the mean snowfall between 1981 and 2010 in NYC...
# 16  Pelham Bay Park is the largest park in New Yor...
# 17  Queens contains the highest population of Asia...
# 18  the Bronx has the largest population of ethnic...
# 19  the number of Hispanic people living in the Ne...
# 20  the Two highest advertising agencies in the wo...
# 21  British Bankers Association was the previous o...
# 22              Manhattan is located in Silicon Alley
# 23  the New York film and television industry crea...
# 24  there are more than 200 newspaper offices loca...
# 25  the name of the citys public television servic...
# 26  the Global Language Monitor ranked New York as...
# 27            there are 24000 restaurants in New York
# 28     the New Jersey Devils hockey team plays Newark
# 29  the Amateur Boxing Golden Gloves takes place a...
# 30  the percentage of New York households that do ...
# 31  the George Washington Bridge is the busiest br...
# 32  President Franklin d Roosevelt was the first p...
# 33  the Second Department of the Supreme Court is ...
#
#                  statement_category        question_category
# 0              PASSIVE_CONSTRUCTION  WHERE_IN_ON_AT_QUESTION
# 1              EXISTENTIAL_SENTENCE             HOW_QUESTION
# 2   SUBJECT_LINKING_VERB_COMPLEMENT            WHAT_QUESTION
# 3               SUBJECT_VERB_OBJECT             WHO_QUESTION
# 4               SUBJECT_VERB_OBJECT            WHAT_QUESTION
# 5     PREPOSITIONAL_PHRASE_FRONTING            WHEN_QUESTION
# 6               SUBJECT_VERB_OBJECT            WHAT_QUESTION
# 7     PREPOSITIONAL_PHRASE_FRONTING             HOW_QUESTION
# 8     PREPOSITIONAL_PHRASE_FRONTING            WHAT_QUESTION
# 9                ATTRIBUTE_IS_VALUE             HOW_QUESTION
# 10             PASSIVE_CONSTRUCTION  WHERE_IN_ON_AT_QUESTION
# 11              SUBJECT_VERB_OBJECT           WHICH_QUESTION
# 12               ATTRIBUTE_IS_VALUE             HOW_QUESTION
# 13             PASSIVE_CONSTRUCTION            WHAT_QUESTION
# 14    PREPOSITIONAL_PHRASE_FRONTING            WHAT_QUESTION
# 15               ATTRIBUTE_IS_VALUE             HOW_QUESTION
# 16  SUBJECT_LINKING_VERB_COMPLEMENT            WHAT_QUESTION
# 17              SUBJECT_VERB_OBJECT            WHAT_QUESTION
# 18              SUBJECT_VERB_OBJECT            WHAT_QUESTION
# 19               ATTRIBUTE_IS_VALUE             HOW_QUESTION
# 20             PASSIVE_CONSTRUCTION            WHAT_QUESTION
# 21  SUBJECT_LINKING_VERB_COMPLEMENT             WHO_QUESTION
# 22             PASSIVE_CONSTRUCTION  WHERE_IN_ON_AT_QUESTION
# 23              SUBJECT_VERB_OBJECT             HOW_QUESTION
# 24             EXISTENTIAL_SENTENCE             HOW_QUESTION
# 25  SUBJECT_LINKING_VERB_COMPLEMENT            WHAT_QUESTION
# 26              SUBJECT_VERB_OBJECT             WHO_QUESTION
# 27             EXISTENTIAL_SENTENCE             HOW_QUESTION
# 28              SUBJECT_VERB_OBJECT           WHICH_QUESTION
# 29              SUBJECT_VERB_OBJECT  WHERE_IN_ON_AT_QUESTION
# 30               ATTRIBUTE_IS_VALUE            WHAT_QUESTION
# 31  SUBJECT_LINKING_VERB_COMPLEMENT           WHICH_QUESTION
# 32  SUBJECT_LINKING_VERB_COMPLEMENT             WHO_QUESTION
# 33             PASSIVE_CONSTRUCTION            WHAT_QUESTION

# %%
pre_training_filename = "pre_training_nyc_samples"
pre_training_filepath = os.path.join(pre_training_dir, pre_training_filename)
if not os.path.exists(pre_training_dir):
    os.makedirs(pre_training_dir)
pre_training_df = filtered_samples_df[["statement_category", "statement", "question_category", "response_question", "response_answer"]].copy()
pre_training_df.to_csv(pre_training_filepath, sep="\t", index=False)
with open(pre_training_filepath, "r") as pre_training_file:
	pre_training_lines = pre_training_file.readlines()
pre_training_lines[:5]
# Out:
# ['statement_category\tstatement\tquestion_category\tresponse_question\tresponse_answer\n',
#  'PASSIVE_CONSTRUCTION\tthe United Nations is headquartered in New York\tWHERE_IN_ON_AT_QUESTION\t? In what city is the United Nations based\tNew York\n',
#  'EXISTENTIAL_SENTENCE\tthere are 120 school and universities in NYC\tHOW_QUESTION\t? How many school and universities are in NYC\t120\n',
#  'SUBJECT_LINKING_VERB_COMPLEMENT\tthe Lenapehoking was the Lenape homeland\tWHAT_QUESTION\t? What was the name of the Lenape homeland\tLenapehoking\n',
#  'SUBJECT_VERB_OBJECT\tEstevao Gomes commanded the Spanish expedition\tWHO_QUESTION\t? Who commanded the Spanish expedition\tEstevao Gomes\n']

# %%
pre_training_automatic_filename = "pre_training_nyc_automatic"
pre_training_automatic_filepath = os.path.join(pre_training_dir, pre_training_automatic_filename)
with open(pre_training_automatic_filepath, "w") as pre_training_automatic_file:
    pre_training_automatic_file.write("#statements\n")
    #write the statements sorted by statement category
    for category, group in pre_training_df.groupby("statement_category"):
        pre_training_automatic_file.write(f"#\n#category: {category}\n")
        for statement in group["statement"]:
            pre_training_automatic_file.write(f"{statement}\n")
    pre_training_automatic_file.write("#\n#questions\n")
    #write the questions sorted by question category
    for category, group in pre_training_df.groupby("question_category"):
        pre_training_automatic_file.write(f"#\n#category: {category}\n")
        for question in group["response_question"]:
            pre_training_automatic_file.write(f"{question}\n")
