# %%
import os
from dataset_processing import question_and_answer_pairs_from_log_file, remove_quotes_from_file, filter_by_max_words, clean_text
import pandas as pd
import platform
from collections import Counter

# %%
operating_system = platform.system()
if operating_system == 'Windows':
    raise Exception("not used on Windows yet")
elif operating_system == 'Linux':
    test_input_dir = "/run/user/1000/gvfs/google-drive:host=gmail.com,user=cjameswalmsley/0AG4X1_cOZQRnUk9PVA/0B24X1_cOZQRnVjZEemxXd3BNSTQ/1SSfZglixkSB5aj0qMv2BsDojVhxNOv0o/11BZhonitY-Jfw5xqM1xAl5TjJPRDRKHr/1OyCmWPf_7PH1bCc-5GLvBdo-gvEvJsiP/1dgL8C9ydesEz3jM28e55yGR9PECRtjaA/1_z0x1Ym8ceREizMlb1mk29msDhvfy2xg/19QWr_JOiOoob5pcpd9aZHJ5kzB4Q0Dc-/1Coru7UDS-tRqhb3jkpMEHM2UyG-hMao_/1DBHxcQpfXReIx0FZn9LRR_aS7VZUuf2V"
    test_log_dir = "/run/user/1000/gvfs/google-drive:host=gmail.com,user=cjameswalmsley/0AG4X1_cOZQRnUk9PVA/0B24X1_cOZQRnVjZEemxXd3BNSTQ/1SSfZglixkSB5aj0qMv2BsDojVhxNOv0o/11BZhonitY-Jfw5xqM1xAl5TjJPRDRKHr/1OyCmWPf_7PH1bCc-5GLvBdo-gvEvJsiP/1dgL8C9ydesEz3jM28e55yGR9PECRtjaA/1_z0x1Ym8ceREizMlb1mk29msDhvfy2xg/19QWr_JOiOoob5pcpd9aZHJ5kzB4Q0Dc-/1Coru7UDS-tRqhb3jkpMEHM2UyG-hMao_/1DZfo5MVzCEfoiO3ulkbx6FMAo8e5o_SX"
    train_dir = "/run/user/1000/gvfs/google-drive:host=gmail.com,user=cjameswalmsley/0AG4X1_cOZQRnUk9PVA/0B24X1_cOZQRnVjZEemxXd3BNSTQ/1SSfZglixkSB5aj0qMv2BsDojVhxNOv0o/11BZhonitY-Jfw5xqM1xAl5TjJPRDRKHr/1OyCmWPf_7PH1bCc-5GLvBdo-gvEvJsiP/1dgL8C9ydesEz3jM28e55yGR9PECRtjaA/1_z0x1Ym8ceREizMlb1mk29msDhvfy2xg/1951JmEhJWAQjilgGc7T00-z9bbiJwNM3"
elif operating_system == 'Darwin': #macOS
    test_log_dir = "/Users/chris/PycharmProjects/dataset/docker/docker_train/shared_data/statements/logs"
    test_input_dir = "/Users/chris/PycharmProjects/dataset/docker/docker_train/shared_data/statements/testing"
    train_dir = "/Users/chris/Library/CloudStorage/GoogleDrive-cjameswalmsley@gmail.com/My Drive/Shared with Julia/Education/Kent University/PhD/work/annabell/training"
else:
    raise Exception("unsupported OS")

test_log_filename = "logfile_squad_test_nyc.txt"
test_input_filename = "test_nyc_questions.txt"
train_filename = "declarative_sentences_train_gemma3:4b_20250617_201822.tsv"

test_log_filepath = os.path.join(test_log_dir, test_log_filename)
test_input_filepath = os.path.join(test_input_dir, test_input_filename)
train_filepath = os.path.join(train_dir, train_filename)

# %%
pre_training_dir ="training"
pre_training_filename = "pre_training_nyc_samples"
pre_training_filepath = os.path.join(pre_training_dir, pre_training_filename)

# %%
with open(pre_training_filepath, "r") as pre_training_file:
	pre_training_lines = pre_training_file.readlines()
pre_training_lines
# Out:
# ['# Group 1: Active Voice Sentences\n',
#  '# These are standard declarative sentences where the subject performs the action of the verb (Subject-Verb-Object).\n',
#  'new york city has the highest population in the united states\n',
#  'new york welcomes the largest number of legal immigrants\n',
#  'New York City comprise -s five borough -s\n',
#  '#\n',
#  '# Group 2: Sentences with a Linking Verb ("to be")\n',
#  '#These sentences use a form of the verb "to be" (is, am, are, was, were) to describe or identify the subject (Subject-Linking Verb-Complement).\n',
#  'the united nations is based in New York\n',
#  'the major gateway for immigration has been in new york city\n',
#  'the most populated city in the united states is new york city\n',
#  '#\n',
#  '# Group 3: Sentences in the Passive Voice\n',
#  '#In these sentences, the subject receives the action of the verb. The structure often involves a form of "to be" plus a past participle.\n',
#  'new york has been called the cultural capital of the world\n',
#  'the five borough -s were combined into one city in 1898\n',
#  'the trading post that preceded New York City was called New Amsterdam\n',
#  '#\n',
#  '#Group 1: Questions Starting with "What" or "Which"\n',
#  '#This group asks for the identification of a person, place, thing, or idea.\n',
#  '? What city in the United States has the highest population\n',
#  '? what city has been called the cultural capital of the world\n',
#  '? What American city welcomes the largest number of legal immigrants\n',
#  '#\n',
#  '# Group 2: Questions Starting with "How"\n',
#  '# This group asks about quantity, amount, or manner.\n',
#  '? How many boroughs comprise New York City\n',
#  '? how many languages are spoken by the people of New York City\n',
#  '? How man boroughs does New York City contain\n',
#  '#\n',
#  '# Group 3: Questions Starting with "In what" or "On what"\n',
#  '# This group asks for specific information related to a time, place, or context.\n',
#  '? in what city is the united nations based\n',
#  '? in what year were the five borough -s combined into one city (appears multiple times)\n',
#  '? in what borough is Wall Street located\n',
#  '#\n',
#  '# Group 4: Questions Starting with "When"\n',
#  '# This group asks for a time, date, or period.\n',
#  '? When was New York City established\n',
#  '? when did the English take over the area from the Dutch\n',
#  '? when was the first European to visit the area of nyc\n',
#  '#\n',
#  '# Group 5: Questions Starting with "Who" or "Whose"\n',
#  '# This group asks for the identification of a person or group.\n',
#  '? who commanded the Spanish expedition\n',
#  '? who was henry hudson working for\n',
#  '? who was the first non-Indian person to live in what is now nyc\n',
#  '#\n',
#  '# Group 6: Questions Starting with "Where"\n',
#  '# This group asks for the identification of a place or location.\n',
#  '? where was Juan Rodriguez born\n',
#  '? where did the stonewall riots happen\n',
#  '? where in Central Park are performances offered at no cost\n',
#  '#\n',
#  '# Group 7: Questions with a Declarative Structure\n',
#  '# This group has a structure similar to a statement, with the question word typically appearing at or near the end.\n',
#  '? the major gateway for immigration has been which US city\n',
#  '? the most populated city in the united states is which city\n',
#  '? the five boroughs of New York City are named what']

# %%
#remove comment lines
pre_training_lines = [line for line in pre_training_lines if not line.startswith("#")]
pre_training_lines
# Out:
# ['new york city has the highest population in the united states\n',
#  'new york welcomes the largest number of legal immigrants\n',
#  'New York City comprise -s five borough -s\n',
#  'the united nations is based in New York\n',
#  'the major gateway for immigration has been in new york city\n',
#  'the most populated city in the united states is new york city\n',
#  'new york has been called the cultural capital of the world\n',
#  'the five borough -s were combined into one city in 1898\n',
#  'the trading post that preceded New York City was called New Amsterdam\n',
#  '? What city in the United States has the highest population\n',
#  '? what city has been called the cultural capital of the world\n',
#  '? What American city welcomes the largest number of legal immigrants\n',
#  '? How many boroughs comprise New York City\n',
#  '? how many languages are spoken by the people of New York City\n',
#  '? How man boroughs does New York City contain\n',
#  '? in what city is the united nations based\n',
#  '? in what year were the five borough -s combined into one city (appears multiple times)\n',
#  '? in what borough is Wall Street located\n',
#  '? When was New York City established\n',
#  '? when did the English take over the area from the Dutch\n',
#  '? when was the first European to visit the area of nyc\n',
#  '? who commanded the Spanish expedition\n',
#  '? who was henry hudson working for\n',
#  '? who was the first non-Indian person to live in what is now nyc\n',
#  '? where was Juan Rodriguez born\n',
#  '? where did the stonewall riots happen\n',
#  '? where in Central Park are performances offered at no cost\n',
#  '? the major gateway for immigration has been which US city\n',
#  '? the most populated city in the united states is which city\n',
#  '? the five boroughs of New York City are named what']

# %%
pre_training_statements = [line for line in pre_training_lines if not line.startswith("?")]
pre_training_statements
# Out:
# ['new york city has the highest population in the united states\n',
#  'new york welcomes the largest number of legal immigrants\n',
#  'New York City comprise -s five borough -s\n',
#  'the united nations is based in New York\n',
#  'the major gateway for immigration has been in new york city\n',
#  'the most populated city in the united states is new york city\n',
#  'new york has been called the cultural capital of the world\n',
#  'the five borough -s were combined into one city in 1898\n',
#  'the trading post that preceded New York City was called New Amsterdam\n']

# %%
pre_training_questions = [line for line in pre_training_lines if line.startswith("?")]
pre_training_questions
# Out:
# ['? What city in the United States has the highest population\n',
#  '? what city has been called the cultural capital of the world\n',
#  '? What American city welcomes the largest number of legal immigrants\n',
#  '? How many boroughs comprise New York City\n',
#  '? how many languages are spoken by the people of New York City\n',
#  '? How man boroughs does New York City contain\n',
#  '? in what city is the united nations based\n',
#  '? in what year were the five borough -s combined into one city (appears multiple times)\n',
#  '? in what borough is Wall Street located\n',
#  '? When was New York City established\n',
#  '? when did the English take over the area from the Dutch\n',
#  '? when was the first European to visit the area of nyc\n',
#  '? who commanded the Spanish expedition\n',
#  '? who was henry hudson working for\n',
#  '? who was the first non-Indian person to live in what is now nyc\n',
#  '? where was Juan Rodriguez born\n',
#  '? where did the stonewall riots happen\n',
#  '? where in Central Park are performances offered at no cost\n',
#  '? the major gateway for immigration has been which US city\n',
#  '? the most populated city in the united states is which city\n',
#  '? the five boroughs of New York City are named what']

# %%
#Load and clean the training data derived from the SQuAD dataset
train_filepath = remove_quotes_from_file(train_filepath)
train_df = pd.read_csv(train_filepath, sep="\t")
train_df = train_df.dropna()

filtered_train_df = train_df[train_df["title"] == "New_York_City"]
filtered_train_df = filter_by_max_words(filtered_train_df, max_words=20)
filtered_train_df["response_question"] = clean_text(filtered_train_df["response_question"], True)
filtered_train_df["response_answer"] = clean_text(filtered_train_df["response_answer"], False)
filtered_train_df["statement"] = clean_text(filtered_train_df["statement"], False)
filtered_train_df.reset_index(drop=True, inplace=True)
filtered_train_df
# Out:
# Cleaned data saved to /run/user/1000/gvfs/google-drive:host=gmail.com,user=cjameswalmsley/0AG4X1_cOZQRnUk9PVA/0B24X1_cOZQRnVjZEemxXd3BNSTQ/1SSfZglixkSB5aj0qMv2BsDojVhxNOv0o/11BZhonitY-Jfw5xqM1xAl5TjJPRDRKHr/1OyCmWPf_7PH1bCc-5GLvBdo-gvEvJsiP/1dgL8C9ydesEz3jM28e55yGR9PECRtjaA/1_z0x1Ym8ceREizMlb1mk29msDhvfy2xg/1951JmEhJWAQjilgGc7T00-z9bbiJwNM3/declarative_sentences_train_gemma3:4b_20250617_201822_cleaned.tsv
#                            id          title  \
# 0    56ce304daab44d1400b8850e  New_York_City
# 1    56ce304daab44d1400b8850f  New_York_City
# 2    56ce304daab44d1400b88510  New_York_City
# 3    56ce304daab44d1400b88511  New_York_City
# 4    56cf5d41aab44d1400b89130  New_York_City
# ..                        ...            ...
# 801  56d1218c17492d1400aaba1e  New_York_City
# 802  56d1218c17492d1400aaba1f  New_York_City
# 803  56d1218c17492d1400aaba20  New_York_City
# 804  56d1218c17492d1400aaba21  New_York_City
# 805  56d121d817492d1400aaba2e  New_York_City
#
#                                               question         answer  \
# 0    What city in the United States has the highest...       New York
# 1            In what city is the United Nations based?       New York
# 2    What city has been called the cultural capital...       New York
# 3    What American city welcomes the largest number...       New York
# 4    The major gateway for immigration has been whi...  New York City
# ..                                                 ...            ...
# 801  What ZIP code was responsible for the greatest...          10021
# 802  How much money in cents does New York City rec...             83
# 803  How much more money does the city give to the ...    $11 billion
# 804  Each year, how much more money does New York C...  $11.4 billion
# 805  In what year did the Sister City Program of th...           2006
#
#                                      response_question     response_answer  \
# 0    ? What city in the United States has the highe...            new york
# 1           ? in what city is the united nations based            new york
# 2    ? what city has been called the cultural capit...            new york
# 3    ? What American city welcomes the largest numb...            new york
# 4    ? the major gateway for immigration has been w...       new york city
# ..                                                 ...                 ...
# 801  ? what ZIP code was responsible for the greate...               10021
# 802  ? how much money in cents does New York City r...                  83
# 803  ? how much more money does the city give to th...          11 billion
# 804  ? each year how much more money does New York ...  11 point 4 billion
# 805  ? in what year did the Sister City Program of ...                2006
#
#                                              statement
# 0    new york city has the highest population in th...
# 1              the united nations is based in New York
# 2    new york has been called the cultural capital ...
# 3    new york welcomes the largest number of legal ...
# 4    the major gateway for immigration has been in ...
# ..                                                 ...
# 801  the ZIP code 10021 was responsible for the gre...
# 802  New York City receives 83 cents for every doll...
# 803  the city gives 11 billion to the state of new ...
# 804  new york city gives 11 point 4 billion more to...
# 805  the Sister City Program of the City of New Yor...
#
# [806 rows x 7 columns]

# %%
#create a new dataframe that has the rows with response_question matching items the pretraining_questions list, plus the rows with statement matching the pretraining_statements list

# Clean up the pre-training lists to match the DataFrame's cleaned text
cleaned_pre_training_questions = [question.strip() for question in pre_training_questions]
cleaned_pre_training_statements = [statement.strip() for statement in pre_training_statements]

# Filter the DataFrame based on the two conditions
questions_mask = filtered_train_df['response_question'].isin(cleaned_pre_training_questions)
statements_mask = filtered_train_df['statement'].isin(cleaned_pre_training_statements)

#'questions_mask = filtered_train_df['response_question'].isin(pre_training_questions)
#statements_mask = filtered_train_df['statement'].isin(pre_training_statements)


# Combine the masks with a logical OR and create the new DataFrame
pre_training_samples_df = filtered_train_df[questions_mask | statements_mask].copy()
pre_training_samples_df.reset_index(drop=True, inplace=True)
pre_training_samples_df
# Out:
#                           id          title  \
# 0   56ce304daab44d1400b8850e  New_York_City
# 1   56ce304daab44d1400b8850f  New_York_City
# 2   56ce304daab44d1400b88510  New_York_City
# 3   56ce304daab44d1400b88511  New_York_City
# 4   56cf5d41aab44d1400b89130  New_York_City
# 5   56cf5d41aab44d1400b89131  New_York_City
# 6   56ce3124aab44d1400b8852a  New_York_City
# 7   56ce3124aab44d1400b8852b  New_York_City
# 8   56cf9d81234ae51400d9be1b  New_York_City
# 9   56cf9d81234ae51400d9be1c  New_York_City
# 10  56cf9d81234ae51400d9be1f  New_York_City
# 11  56ce31baaab44d1400b8853a  New_York_City
# 12  56ce31baaab44d1400b8853d  New_York_City
# 13  56cf9df0234ae51400d9be25  New_York_City
# 14  56ce32e7aab44d1400b88552  New_York_City
# 15  56cfa06a234ae51400d9be39  New_York_City
# 16  56ce34c7aab44d1400b88595  New_York_City
# 17  56ce3569aab44d1400b885ab  New_York_City
# 18  56ce362aaab44d1400b885bc  New_York_City
# 19  56cfabed234ae51400d9be49  New_York_City
# 20  56ceddd9aab44d1400b88b5f  New_York_City
# 21  56ceddd9aab44d1400b88b60  New_York_City
# 22  56cee5a1aab44d1400b88c25  New_York_City
# 23  56cee5a1aab44d1400b88c26  New_York_City
# 24  56cfdc71234ae51400d9bf88  New_York_City
# 25  56cf578daab44d1400b8908c  New_York_City
# 26  56d1062317492d1400aab76e  New_York_City
# 27  56d1186417492d1400aab913  New_York_City
#
#                                              question  \
# 0   What city in the United States has the highest...
# 1           In what city is the United Nations based?
# 2   What city has been called the cultural capital...
# 3   What American city welcomes the largest number...
# 4   The major gateway for immigration has been whi...
# 5   The most populated city in the United States i...
# 6           How many boroughs comprise New York City?
# 7   In what year were the five boroughs combined i...
# 8        How man boroughs does New York City contain?
# 9   The five boroughs of New York City are named w...
# 10  How many languages are spoken by the people of...
# 11  What was the trading post that preceded New Yo...
# 12  When did the English take over the area from t...
# 13                When was New York City established?
# 14            In what borough is Wall Street located?
# 15  When was the first European to visit the area ...
# 16              Who commanded the Spanish expedition?
# 17                  Who was Henry Hudson working for?
# 18                     Where was Juan Rodriguez born?
# 19  Who was the first non-Indian person to live in...
# 20  In 1730, what percentage of New York household...
# 21  In 1730, what American city had the highest pe...
# 22  In 1860, what fraction of the city population ...
# 23  In 1860, what percentage of the city populatio...
# 24              Where did the Stonewall riots happen?
# 25  Where in Central Park are performances offered...
# 26  In the first half of 2010, what percentage of ...
# 27  In 2011, what airport did the most internation...
#
#                                                answer  \
# 0                                            New York
# 1                                            New York
# 2                                            New York
# 3                                            New York
# 4                                       New York City
# 5                                       New York City
# 6                                                five
# 7                                                1898
# 8                                                five
# 9   Brooklyn, Queens, Manhattan, the Bronx, and St...
# 10                                                800
# 11                                      New Amsterdam
# 12                                               1664
# 13                                               1624
# 14                                          Manhattan
# 15                                               1524
# 16                                      Estêvão Gomes
# 17                           Dutch East India Company
# 18                                      Santo Domingo
# 19                                     Juan Rodriguez
# 20                                                42%
# 21                         Charleston, South Carolina
# 22                                          a quarter
# 23                                                25%
# 24  Stonewall Inn in the Greenwich Village neighbo...
# 25                                        Summerstage
# 26                                              95.9%
# 27              John F. Kennedy International Airport
#
#                                     response_question  \
# 0   ? What city in the United States has the highe...
# 1          ? in what city is the united nations based
# 2   ? what city has been called the cultural capit...
# 3   ? What American city welcomes the largest numb...
# 4   ? the major gateway for immigration has been w...
# 5   ? the most populated city in the united states...
# 6          ? How many boroughs comprise New York City
# 7   ? in what year were the five borough -s combin...
# 8       ? How man boroughs does New York City contain
# 9   ? the five boroughs of New York City are named...
# 10  ? how many languages are spoken by the people ...
# 11  ? What was the trading post that preceded New ...
# 12  ? when did the English take over the area from...
# 13               ? When was New York City established
# 14           ? in what borough is Wall Street located
# 15  ? when was the first European to visit the are...
# 16             ? who commanded the Spanish expedition
# 17                 ? who was henry hudson working for
# 18                    ? where was Juan Rodriguez born
# 19  ? who was the first non-Indian person to live ...
# 20  ? in what year were the five borough -s combin...
# 21  ? in what year were the five borough -s combin...
# 22  ? in what year were the five borough -s combin...
# 23  ? in what year were the five borough -s combin...
# 24             ? where did the stonewall riots happen
# 25  ? where in Central Park are performances offer...
# 26  ? in what year were the five borough -s combin...
# 27  ? in what year were the five borough -s combin...
#
#                                       response_answer  \
# 0                                            new york
# 1                                            new york
# 2                                            new york
# 3                                            new york
# 4                                       new york city
# 5                                       new york city
# 6                                                five
# 7                                                1898
# 8                                                five
# 9   brooklyn queens manhattan the bronx and staten...
# 10                                                800
# 11                                      New Amsterdam
# 12                                               1664
# 13                                               1624
# 14                                          Manhattan
# 15                                               1524
# 16                                      estevao gomes
# 17                           Dutch East India Company
# 18                                      Santo Domingo
# 19                                     juan rodriguez
# 20                                               1898
# 21                                               1898
# 22                                               1898
# 23                                               1898
# 24  stonewall inn in the greenwich village neighbo...
# 25                                        summerstage
# 26                                               1898
# 27                                               1898
#
#                                             statement
# 0   new york city has the highest population in th...
# 1             the united nations is based in New York
# 2   new york has been called the cultural capital ...
# 3   new york welcomes the largest number of legal ...
# 4   the major gateway for immigration has been in ...
# 5   the most populated city in the united states i...
# 6           New York City comprise -s five borough -s
# 7   the five borough -s were combined into one cit...
# 8              New York City contains five borough -s
# 9   the five borough -s of New York City are named...
# 10    the people of New York City speak 800 languages
# 11  the trading post that preceded New York City w...
# 12  the English took over the area from the Dutch ...
# 13              New York City was established in 1624
# 14  Wall Street is located in the borough of Manha...
# 15  the first European to visit the area of nyc ar...
# 16     estevao gomes commanded the Spanish expedition
# 17  henry hudson was working for the Dutch East In...
# 18           Juan Rodriguez was born in Santo Domingo
# 19  juan rodriguez was the first non-indian person...
# 20  the five borough -s were combined into one cit...
# 21  the five borough -s were combined into one cit...
# 22  the five borough -s were combined into one cit...
# 23  the five borough -s were combined into one cit...
# 24  the stonewall riots happened at stonewall inn ...
# 25  performances are offered at no cost in summers...
# 26  the five borough -s were combined into one cit...
# 27  the five borough -s were combined into one cit...

# %%
print(f"number of pre_training_questions: {len(pre_training_questions)}")
print(f"number of pre_training_statements: {len(pre_training_statements)}")
# Out:
# number of pre_training_questions: 21
# number of pre_training_statements: 9

# %%
 bag_of_statements = Counter(statements_mask.values)
 bag_of_statements
# Out:
# Counter({np.False_: 791, np.True_: 15})

# %%
cleaned_pre_training_statements
# Out:
# ['new york city has the highest population in the united states',
#  'new york welcomes the largest number of legal immigrants',
#  'New York City comprise -s five borough -s',
#  'the united nations is based in New York',
#  'the major gateway for immigration has been in new york city',
#  'the most populated city in the united states is new york city',
#  'new york has been called the cultural capital of the world',
#  'the five borough -s were combined into one city in 1898',
#  'the trading post that preceded New York City was called New Amsterdam']
